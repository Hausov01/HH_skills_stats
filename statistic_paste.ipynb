# %%
import pandas as pd
df = pd.read_csv('data/old/hh_skills_rpa_аналитик_113.csv', delimiter=',')
df.head(30)
# Out:
#                                    Навык  Количество Процент
# 0                                    SQL           7   6.31%
# 1         Разработка технических заданий           4   3.60%
# 2                                 Python           4   3.60%
# 3                 Аналитическое мышление           3   2.70%
# 4                Анализ бизнес-процессов           3   2.70%
# 5         Постановка задач разработчикам           2   1.80%
# 6                                  Agile           2   1.80%
# 7                      Анализ требований           2   1.80%
# 8              Описание бизнес-процессов           2   1.80%
# 9                               Power BI           2   1.80%
# 10        Автоматизация бизнес-процессов           2   1.80%
# 11                            PostgreSQL           2   1.80%
# 12                                   RPA           2   1.80%
# 13                           B2B Продажи           2   1.80%
# ...

# %%
df = pd.read_csv('data/old/hh_skills_бизнес_аналитик_113.csv', delimiter=',')
df.head(30)
# Out:
#                                   Навык  Количество Процент
# 0                         Бизнес-анализ         165   6.24%
# 1                Аналитическое мышление          99   3.74%
# 2                                  BPMN          96   3.63%
# 3                                   SQL          89   3.37%
# 4               Анализ бизнес-процессов          76   2.87%
# 5                      Системный анализ          56   2.12%
# 6                              MS Excel          55   2.08%
# 7          Оптимизация бизнес-процессов          55   2.08%
# 8        Разработка технических заданий          50   1.89%
# 9        Постановка задач разработчикам          49   1.85%
# 10            Описание бизнес-процессов          46   1.74%
# 11                                  UML          41   1.55%
# 12       Моделирование бизнес-процессов          39   1.48%
# 13       Автоматизация бизнес-процессов          39   1.48%
# 14                        Анализ данных          31   1.17%
# ...

# %%
df = pd.read_csv('data/old/hh_skills_менеджер_проекта_113.csv', delimiter=',')
df.head(30)
# Out:
#                                   Навык  Количество Процент
# 0                  Деловая коммуникация         114   3.79%
# 1                     Деловая переписка          99   3.29%
# 2                  Управление проектами          89   2.96%
# 3                Организаторские навыки          87   2.89%
# 4                       Деловое общение          58   1.93%
# 5                   Ведение переговоров          53   1.76%
# 6                  Заключение договоров          52   1.73%
# 7                      Работа в команде          51   1.70%
# 8                  Проектный менеджмент          43   1.43%
# 9                 Телефонные переговоры          37   1.23%
# 10  Работа с большим объемом информации          37   1.23%
# 11                   Project management          30   1.00%
# 12                 Планирование бюджета          26   0.86%
# 13            Управление коммуникациями          26   0.86%
# 14                  Управление командой          26   0.86%
# ...

# %%
df = pd.read_csv('data/old/hh_skills_руководитель_проекта_113.csv', delimiter=',')
df.head(30)
# Out:
#                              Навык  Количество Процент
# 0             Управление проектами         107   3.92%
# 1           Организаторские навыки          99   3.63%
# 2             Деловая коммуникация          88   3.22%
# 3                Деловая переписка          64   2.34%
# 4           Проектная документация          50   1.83%
# 5              Ведение переговоров          48   1.76%
# 6                    Строительство          42   1.54%
# 7                       MS Project          40   1.47%
# 8              Управление командой          40   1.47%
# 9                 Работа в команде          37   1.36%
# 10            Проектный менеджмент          36   1.32%
# 11     Основы управления проектами          35   1.28%
# 12            Планирование бюджета          33   1.21%
# 13                 Деловое общение          32   1.17%
# 14            Заключение договоров          30   1.10%
# 15              Управление рисками          29   1.06%
# ...

# %%
df = pd.read_csv('data/old/hh_skills_системный_аналитик_113.csv', delimiter=',')
df.head(30)
# Out:
#                                   Навык  Количество Процент
# 0                                   SQL         182   6.00%
# 1                      Системный анализ         180   5.94%
# 2                                  BPMN         161   5.31%
# 3                                   UML         141   4.65%
# 4                         Бизнес-анализ          82   2.70%
# 5        Постановка задач разработчикам          76   2.51%
# 6        Разработка технических заданий          63   2.08%
# 7                                  REST          58   1.91%
# 8                                  SOAP          55   1.81%
# 9                                   API          54   1.78%
# 10               Аналитическое мышление          53   1.75%
# 11                                  XML          48   1.58%
# 12                             REST API          42   1.39%
# 13                                 JSON          41   1.35%
# 14                       Atlassian Jira          36   1.19%
# ...

# %%
df = pd.read_csv('data/old/hh_skills_финансовый_аналитик_113.csv', delimiter=',')
df.head(30)
# Out:
#                                     Навык  Количество Процент
# 0                       Финансовый анализ         329   8.17%
# 1                   Финансовая отчетность         166   4.12%
# 2                          Бюджетирование         147   3.65%
# 3                     Финансовый контроль         136   3.38%
# 4                 Финансовое планирование         126   3.13%
# 5               Управленческая отчетность         119   2.96%
# 6                                MS Excel         106   2.63%
# 7                    Экономический анализ          88   2.19%
# 8                   Финансовый менеджмент          86   2.14%
# 9                  Аналитическое мышление          85   2.11%
# 10  Формирование аналитической отчетности          76   1.89%
# 11                  Финансовые показатели          71   1.76%
# 12               Финансовое моделирование          71   1.76%
# 13          Анализ финансовых показателей          60   1.49%
# ...
